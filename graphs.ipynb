# %%
from funcs import *
import matplotlib.pyplot as plt
import numpy as np

# %%
sens = 50
carbratio = 20

# %%
sens = 50
carbratio = 20
simlengthseg = 60*60
dt = 0.1
n = simlengthseg / dt
temp = np.arange(0,simlengthseg,dt)

initialBG = 100
simbg = [initialBG]*int(n)
G = [0.0]*int(n)

# %%
AT=int(240/dt)
for t in range (0, AT):
    G[t] = deltaBGC(t, sens, carbratio, 30, int(90/dt) ) + simbg[t] + deltaBGI(t*dt, 2, sens, 3)

# %%
plt.plot(temp[0:AT],G[0:AT])

# %%
AT=int(240/dt)
for t in range (0, AT):
    G[t] = deltaBGC(t, sens, carbratio, 30, int(90/dt) ) + simbg[t] + deltatempBGI(t*dt,0.03,sens,3,0,30) 
print(G[769])
# Out:
# 155.06411096318902

# %%
plt.plot(temp[0:AT],G[0:AT])

# %%
AT=int(240/dt)
for t in range (0, AT):
    G[t] = simbg[t] + deltatempBGI(t*dt,0.03,sens,3,0,30)
print(G[t])
# Out:
# 55.0

# %%
plt.plot(temp[0:AT],G[0:AT])

# %%
AT=int(240/dt)
for t in range (0, AT):
    G[t] = deltaBGC(t, sens, carbratio, 30, int(90/dt) ) + simbg[t] 
print(G[769])
# Out:
# 171.82203703703703

# %%
plt.plot(temp[0:AT],G[0:AT])
